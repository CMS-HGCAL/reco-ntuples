# %%
#imports and setup
# %matplotlib notebook
# %cd '/home/naodell/work/CMS/hgcal/RecoNtuples/HGCalAnalysis'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import plotly.plotly as plotly
import plotly.graph_objs as go
# Out:
# /home/naodell/work/CMS/hgcal/RecoNtuples/HGCalAnalysis

# %% [markdown]
# # Exploring HGCal
#
# Let's take a look at some hgcal data.  First some simple visualizations...

# %%
event_data = pd.read_csv('data/test.csv')
event_data.hist(column='e', range=(0., 2.), bins=100, histtype='step', lw=2)
plt.yscale('log')
plt.xlabel('rechit energy')
plt.ylabel('hits')
plt.title('')
plt.xlim([0., 2.])
# Out:
# <img src="data:image/png;base64,..." width="639.2857251726853">
# (0.0, 2.0)

# %%
sd = event_data.query('0.05 < e and 320. < z')

cscale = sd.e/(sd.e.max() - sd.e.min())

#fig = plt.figure()
#ax  = fig.add_subplot(111, projection='3d')
#ax.scatter(sd.z, sd.x, sd.y, cmap='viridis', c=sd.e, s=2, alpha=0.25)
#ax.set_xlabel('z')
#ax.set_ylabel('x')
#ax.set_zlabel('y')

trace1 = go.Scatter3d(x=sd.x, y=sd.z, z=sd.y, mode='markers',
                      marker=dict(
                      size=1,
                      color=cscale,             # set color to an array/list of desired values
                      colorscale='Viridis',   # choose a colorscale
                      opacity=0.8
                      )
                    )

data   = [trace1]
layout = go.Layout(margin=dict(l=0, r=0, b=0, t=0),
                   scene=dict(xaxis=dict(title='x (cm)'), yaxis=dict(title='z (cm)'), zaxis=dict(title='y (cm)'))
                  )
fig    = go.Figure(data=data, layout=layout)
plotly.iplot(fig, filename='3d-scatter-colorscale')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~najodell/0 or inside your plot.ly account where it is named '3d-scatter-colorscale'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~najodell/0.embed" height="525px" width="100%"></iframe>
